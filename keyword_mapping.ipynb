# %%
# download the pretrained model and extract
# !wget https://nlp.h-its.org/bpemb/fi/fi.wiki.bpe.vs200000.d300.w2v.txt.tar.gz
# !tar xvzf fi.wiki.bpe.vs200000.d300.w2v.txt.tar.gz


# This is the pretrained model from facebook research fasttext, damn slow, huge but bad performance
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.fi.300.vec.gz
# !gunzip cc.fi.300.vec.gz

# %%
import os
import re
import random
import requests
import pickle
import multiprocessing
import pandas as pd
import numpy as np

from sklearn.manifold import TSNE

from gensim import corpora, downloader
from gensim.utils import simple_preprocess, tokenize
from gensim.models import KeyedVectors, Word2Vec
from gensim.test.utils import datapath
from gensim.models.fasttext import FastText

import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import warnings

import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %matplotlib inline


warnings.filterwarnings('ignore')

# %%
df = pd.read_json('data/topics.json')

# %%
df.head()
# Out:
#                                             keywords  topic_id
# 0  [[audi, 0.0081285564], [keuhkosyövän, 0.005977...         0
# 1  [[sopii, 0.0092158103], [ford, 0.008776377], [...         1
# 2  [[jorma, 0.0219070092], [marja, 0.0090980381],...         2
# 3  [[duodecim, 0.010550919], [hoito, 0.0075704153...         3
# 4  [[kilpirauhasen, 0.051186423700000004], [vajaa...         4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
# keywords    30 non-null object
# topic_id    30 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 560.0+ bytes

# %%
# what else we can do with this?
# First, transfer words to id

# create pairs of keyword - topic

# %%
# %%time
# load pretrained w2v, this would take mins on google collab
gensim_embeds = KeyedVectors.load_word2vec_format('data/fi/fi.wiki.bpe.vs200000.d300.w2v.txt', binary=False)
pretrained_embeds = gensim_embeds.vectors
# To convert words in the input tweet to indices of the embeddings matrix:
word_to_idx = {word: i for i, word in enumerate(gensim_embeds.vocab.keys())}
# Out:
# CPU times: user 1min 25s, sys: 576 ms, total: 1min 26s
# Wall time: 1min 25s

# %%
BATCH_SIZE = 10
EMBEDDING_SIZE = 300  # Dimension of the embedding vector
HIDDEN_SIZE = 300
N_CLASSES = len(df)

LR = 0.001
N_EPOCH = 30
REPORT_EVERY=1

# check if GPU available
USE_CUDA = torch.cuda.is_available()

WORKERS = multiprocessing.cpu_count()

device = torch.device("cuda" if USE_CUDA else "cpu")
torch.set_num_threads(WORKERS)
np.random.seed(12)

print(device, WORKERS)
# Out:
# cpu 8

# %%
#--- model ---

class FFNN(nn.Module):
    # Note that pretrained_embeds is a numpy matrix of shape (num_embeddings, embedding_dim)
    def __init__(self, pretrained_embeds, n_classes, n_hidden):
        super(FFNN, self).__init__()
        # get the dimension of the embedding
        embed_dim = pretrained_embeds.shape[1]
        
        self.embed = nn.Embedding.from_pretrained(torch.FloatTensor(pretrained_embeds))
        print(self.embed)
        self.fc1 = nn.Linear(embed_dim, n_hidden) 
        self.fc2 = nn.Linear(n_hidden, n_classes)

    def forward(self, x):
        embeds = self.embed(x)
        # print('embed: ', embeds.shape)
        h1 = F.relu(self.fc1(embeds))
        
        # print('h1', h1.shape)
        out = self.fc2(h1)

        return F.log_softmax(out, dim=1)

# %%
def make_label(topics):
    return torch.FloatTensor(topics)


def make_trainset(df, indices, w2v):
    """
    For each word in trainset, find similar words by w2v model and assign the
    label as the test
    """
    trainset = []
    testset = []
    count_missing = 0
    
    for index, row in df.iterrows():
        topic = row['topic_id']
        for word in row['keywords']:
            if word[0] not in indices:
                count_missing += 1
                continue
                
            word_idx = torch.tensor([indices[word[0]]], dtype=torch.long) 
            target = torch.tensor([topic], dtype=torch.long)
            
            similars = w2v.similar_by_word(word[0], topn=10)
            
            testset += [[torch.tensor([indices[s[0]]], dtype=torch.long), target] for s in similars]
            
            trainset.append([word_idx, target])
            
            
            
    print('Words missing from the w2v model:', count_missing)
    
    return trainset, testset

# %%
# %%time
trainset, testset = make_trainset(df, word_to_idx, gensim_embeds)
# Out:
# Words missing from the w2v model: 611
# CPU times: user 1min 58s, sys: 576 ms, total: 1min 58s
# Wall time: 15.7 s

# %%
len(trainset), len(testset)
# Out:
# (889, 8890)

# %% [markdown]
# **As we can see above, the word missing in pretrained model is 611, which is a lot. The reason might be the words in corpus is not in base form, which require lemmatizing. However we don't have a good lemma tool for Finnish yet.**

# %%
#--- set up ---
model = FFNN(pretrained_embeds, N_CLASSES, HIDDEN_SIZE).to(device)
loss_function = nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr=LR)
# Out:
# Embedding(200000, 300)

# %%
#--- training ---
for epoch in range(N_EPOCH):
    total_loss = 0
    # correct = 0
    for i in trainset:  
        gold_class = i[1].to(device)
        # print(gold_class.shape)

        word_indice = i[0].to(device)
        # print(word_indice.shape)
        
        log_probs = model(word_indice)
        
        # print('log probs:', log_probs.shape)
        
        loss = loss_function(log_probs, gold_class)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        _, predicted = torch.max(log_probs, 1)

    if ((epoch+1) % REPORT_EVERY) == 0:
        print('epoch: %d, loss: %.4f' % (epoch, total_loss*100/len(trainset)))
# Out:
# epoch: 0, loss: 339.8579
# epoch: 1, loss: 338.0556
# epoch: 2, loss: 336.3088
# epoch: 3, loss: 334.5860
# epoch: 4, loss: 332.8649
# epoch: 5, loss: 331.1235
# epoch: 6, loss: 329.3443
# epoch: 7, loss: 327.5109
# epoch: 8, loss: 325.6047
# epoch: 9, loss: 323.6154
# epoch: 10, loss: 321.5284
# epoch: 11, loss: 319.3354
# epoch: 12, loss: 317.0239
# epoch: 13, loss: 314.5836
# epoch: 14, loss: 312.0142
# epoch: 15, loss: 309.3100
# epoch: 16, loss: 306.4664
# epoch: 17, loss: 303.4831
# epoch: 18, loss: 300.3673
# epoch: 19, loss: 297.1202
# epoch: 20, loss: 293.7449
# epoch: 21, loss: 290.2544
# epoch: 22, loss: 286.6546
# epoch: 23, loss: 282.9548
# epoch: 24, loss: 279.1705
# epoch: 25, loss: 275.3135
# epoch: 26, loss: 271.3952
# epoch: 27, loss: 267.4281
# epoch: 28, loss: 263.4205
# epoch: 29, loss: 259.3848

# %%
#--- test ---
def test_model(testset, n_topics=5):
    """
    This test is the correct counted for any match in top n_topics
    The idea is, if we try to match exact the target, the chance is really low
    Because of the keywords number is small + topics is over lapping.
    The reasonable test is check if predicted value in the top n of target
    """
    correct = 0
    with torch.no_grad():
        for i in testset:
            gold_class = i[1].to(device)

            word_indices = i[0].to(device)

            log_probs = model(word_indices)
            # print(log_probs)
            _, predicted = log_probs.topk(n_topics, 1)
            result = predicted.squeeze(0).data.cpu().numpy()
            target = gold_class.data.cpu().numpy()[0]
            # print(result, target)

            correct += 1 if target in result else 0

    print('test accuracy: %.2f' % (100.0 * correct / len(testset) ))

# %%
test_model(testset, n_topics=5)
# Out:
# test accuracy: 54.16

# %%
def predict_topics(keyword, model, indices, n_topics=5):
    word_idx = torch.tensor([indices[keyword]], dtype=torch.long)
    
    log_probs = model
    log_probs = model(word_idx)
    # print(log_probs)
    _, predicted = log_probs.topk(n_topics, 1)
    result = predicted.squeeze(0).data.cpu().numpy()
    
    return result

# %%
topics_pred = predict_topics('omena', model, word_to_idx)

# %%
print(topics_pred)
# Out:
# [ 1  2 29 23  9]

# %% [markdown]
# ## Horray, we have been working on a long path, all the materials are ready to cook some food.

# %%
# First we need to get the doc_topics from previos LDA training

df_doc_topics = pd.read_csv('data/doc_topics.csv')

# %%
df_doc_topics.head()
# Out:
#                                                 uuid   topic_0   topic_1  \
# 0  QXJ0aWNsZTpjZDUwZDI5Mi1jYjk5LTRlZmYtYWVmNC0yZm...  0.042724  0.023630
# 1  QXJ0aWNsZTo5OTQ0MjNkYy04ZTljLTQxZTItOGQyNy0xMT...  0.000068  0.000072
# 2  QXJ0aWNsZTplNGZiM2EwOS01MTI2LTRkYTctYjEzOS1jYz...  0.000093  0.000099
# 3  QXJ0aWNsZTphOTQyMzU3YS01OGRkLTQ2ZTQtOGIyNC1hZW...  0.000083  0.000088
# 4  QXJ0aWNsZTpkZDllOTM3ZS1iZWE3LTQxMDEtODAwNS00MT...  0.000061  0.013003
#
#     topic_2   topic_3   topic_4   topic_5   topic_6   topic_7   topic_8  \
# 0  0.000075  0.000251  0.000065  0.000093  0.000148  0.039949  0.000148
# 1  0.000069  0.000231  0.000060  0.005728  0.000136  0.000119  0.000136
# 2  0.000095  0.000316  0.000082  0.000117  0.000186  0.000163  0.207305
# 3  0.000084  0.000281  0.000073  0.000104  0.000165  0.000144  0.000165
# 4  0.000062  0.000208  0.000054  0.000077  0.000122  0.000107  0.020730
#
#      ...     topic_20  topic_21  topic_22  topic_23  topic_24  topic_25  \
# 0    ...     0.000262  0.033658  0.000084  0.034273  0.000102  0.000103
# 1    ...     0.000241  0.029914  0.000078  0.039052  0.000094  0.000094
# 2    ...     0.000330  0.046230  0.000106  0.000120  0.000129  0.000129
# 3    ...     0.000293  0.000103  0.000094  0.031181  0.000114  0.003296
# 4    ...     0.000217  0.111349  0.000070  0.007153  0.000085  0.000085
#
#    topic_26  topic_27  topic_28  topic_29
# 0  0.003250  0.443131  0.005510  0.084713
# 1  0.000113  0.827827  0.000072  0.020712
# 2  0.000154  0.463375  0.000099  0.273360
# 3  0.000137  0.614437  0.000088  0.092755
# 4  0.000101  0.793116  0.000065  0.000140
#
# [5 rows x 31 columns]

# %%
# now we the the list of topics from the query
# could use them to find the top N documents relevant

def query_article_by_keyword(keyword, df_docs, model, indices, n_topics=5, n_docs=10):
    # get the n_topics by keywords:
    topics = predict_topics(keyword, model, indices, n_topics)
    # get n_docs for each topics
    list_doc = []
    
    for topic in topics:
        docs = df_docs.sort_values('topic_' + str(topic), ascending=False).head(n_docs)
        list_doc += docs['uuid'].tolist()
        
    return list(set(list_doc))

# %%
# First get the article ids from the query
article_ids = query_article_by_keyword("omena", df_doc_topics, model, word_to_idx)

# %%
# niceee, now let get the article content from this
df_article = pd.read_json('data/dataset.json')

# %%
df_article.head()
# Out:
#                                                 body  \
# 0  Vuonna 1978 valmistuneen mökin lautaverhoilu o...
# 1  Yrittäjäpariskunta Anu ja Heikki asuvat Rymätt...
# 2  Sirpan koti sijaitsee vuonna 1907 rakennetussa...
# 3  Moderni hirsitalo\r\nAsukkaat: sisustussuunnit...
# 4  Saarekkeen ääressä on kiva juoda aamukahvit, n...
#
#                                           categories  \
# 0                                            [Mökit]
# 1                         [Keittiö, Keittiöremontti]
# 2                   [Kodit, Skandinaavinen sisustus]
# 3                          [Rakentaminen, Hirsitalo]
# 4  [Kodit, Ennen ja jälkeen, Keittiöremontti, Rem...
#
#                                          description  \
# 0  Suvin ja Kallen mökki on niin lähellä perheen ...
# 1  Anu ja Heikki halusivat laadukkaan keittiön, j...
# 2  Kun arvostaa elämän pieniä nautintoja, taidett...
# 3  Moderni hirsitalo, entinen perhekoti ja muutto...
# 4  Kun Satu ja Kyösti Melametsä rakennuttivat per...
#
#                                                   id  mainCategory  \
# 0  QXJ0aWNsZTpjZDUwZDI5Mi1jYjk5LTRlZmYtYWVmNC0yZm...  Meidän Mökki
# 1  QXJ0aWNsZTo5OTQ0MjNkYy04ZTljLTQxZTItOGQyNy0xMT...      Avotakka
# 2  QXJ0aWNsZTplNGZiM2EwOS01MTI2LTRkYTctYjEzOS1jYz...      Avotakka
# 3  QXJ0aWNsZTphOTQyMzU3YS01OGRkLTQ2ZTQtOGIyNC1hZW...   Meidän Talo
# 4  QXJ0aWNsZTpkZDllOTM3ZS1iZWE3LTQxMDEtODAwNS00MT...   Meidän Talo
#
#        published          subCategory  \
# 0  1550043116000             Sisustus
# 1  1549969080000             Sisustus
# 2  1549960923000             Sisustus
# 3  1549959061000  Rakenna ja remontoi
# 4  1549956919000  Rakenna ja remontoi
#
#                                                title     type         venue
# 0  Makkaranpaistoa tulipadassa ja lämpimänä höyry...  Article  meillakotona
# 1  Hirsitalon keittiö remontoitiin tähän päivään ...  Article  meillakotona
# 2  Jugendtalon rappukäytävä lumosi Sirpan – koti ...  Article  meillakotona
# 3  Haaveena oma talo? Lue kolme erilaista tarinaa...  Article  meillakotona
# 4  Keittiöremontti käynnisti ketjureaktion! Teini...  Article  meillakotona

# %% [markdown]
# ### Finally we made it, now we got the articles based on keyword query, whatever keywords are! (not quite sure)

# %%
df_article[df_article['id'].isin(article_ids)]
# Out:
#                                                    body  \
# 71    Muodista, kauneudesta ja matkoista bloggaava H...
# 195   Joulukuusissa on nykyään paljon valinnanvaraa....
# 330   1. Kotimaista pellavaa\r\n\nLastu-pyyhe, 16,90...
# 503   Kun illat viilenevät ja hämärtyvät, tekee miel...
# 558   Uuden Hento lumisade -mukin kuvitus pohjautuu ...
# 575   Miten päädyit veistämään kihlasormuksen tyttöy...
# 669   Tuplakurkku yllätti voileipäpöydässä\nKaksi vi...
# 688   Porin asuntomessujen vilinässä valkoisten ja k...
# 717   Mansikoiden pakastaminen viipaleina\nPienen pa...
# 760   Kohde 26: Talo Haltiatar\r\n\nHuonejako, kerro...
# 762   Kohde 3: As Oy Porin Jokisimpukka\r\n\nHuoneja...
# 812   Angervot ovat erittäin suosittuja koristepensa...
# 1041  1. Mattamustat kaapistot\n\nL-mallinen keittiö...
# 1131  Muistan yhä ajan, kun aloin ymmärtää shoppailu...
# 1169  String-hylly sopii kaikkiin kodin tiloihin. Mu...
# 1397  Parhaat kirjoitukset julkistetaan Eevan tähdet...
# 2073  SEO on pitänyt paikkansa suomalaisessa huoltoa...
# 2653  Linja-autoliitto ja Liikenneturva haluavatkin ...
# 2721  Sain kesälomalla tilaisuuden katsella horisont...
# 2792  Olin niin häkeltynyt Jennan paljastuksesta, et...
# 2862  ”Hankin Oivan nelisen vuotta sitten suomalaise...
# 2901  Monet ihmiset rakastavat työtään, ainakin he v...
# 3340  Irrallaan autossa matkustava koira on turvalli...
# 3619  Hanna Sumarin äiti pani tyttärensä laihdutusku...
# 3955  Ohjelma:\r\n4.8. Lauantai. Lähtö klo 7.30 Hels...
# 3990  Ohjelma: \r\n4.8. Lauantai. Lähtö klo 7.30 Hel...
# 4435  Lapsena Milana Misicin, 47, elämää varjostivat...
# 4440  Imagen autokoulu on juttuhanke, jossa Jyrki Le...
# 4466  Laulaja Milana Misicin, 47, elämää varjostivat...
# 4671  Risteilyllä tanssitaan, syödään hyvin, rentoud...
# 4730  Kahden eri-ikäisen naisen ystävyys alkoi legen...
# 4754  Näyttelijä Marja Salo, 37, puikkelehtii tottun...
# 4926  Myanmarin työläisnorsut ovat yksilöitä siinä m...
# 4961  Noin joka kuudes kaikista vastaajista (16 %) r...
# 5244  Risteilyohjelma: \r\nSu 18.3.\r\n16:00 Lähtöse...
# 5338  Pitkä ajomatka Lapin tuntureille on useimmiten...
# 5462  Laulaja Anita Hirvosen elämää määrittää usko J...
# 5512  Selviytyjät Suomi -sarjassa mukana ollut Katja...
# 5776  Muumipeikko ja taikurin hattu on viehättävä ko...
# 5874  Suomalainen Energiaosuuskunta täyttää tänä vuo...
# 5985  Valkoinen putosi kolmanneksi 2017 oltuaan suos...
# 6148  Leipäannoksia ruumiilta\nNuori mies Onni Johan...
# 6281  Asenne kohdalleen\nPositiivinen ajattelu on hy...
# 6397  Mummola tulee uniin\nNäen paljon unia. Ne vahv...
# 6404  Värien värähtelyä\nMinulla on aina yksi väri,\...
# 6621  Marjojen terveyshyödyt tunnetaan, mutta mikä o...
# 6624  1. Polkkatukka pään yli kammattuna tuo tyyliin...
# 6631  1. Maailman seksikkäimmäksi naiseksi monesti v...
# 6838  Terapeutti Tommy Hellsten on tehnyt elämässään...
# 7231  Tämän kevään hiustrendi sopii hyvin suomalaise...
#
#                                            categories  \
# 71                                                 []
# 195                               [Joulu, Joulukukat]
# 330                           [Design, Sisustusideat]
# 503                       [Remontointi, Rakentaminen]
# 558                                         [Keittiö]
# 575                                       [Askartelu]
# 669                      [Puutarhan kasvit, Kasvimaa]
# 688          [Asuntomessut, Kodit, Asuntomessut 2018]
# 717   [Sadonkorjuu, Marjat, Säilöntä, Ruoanvalmistus]
# 760                 [Asuntomessut, Asuntomessut 2018]
# 762                 [Asuntomessut, Asuntomessut 2018]
# 812                [Puutarhan kasvit, Koristepensaat]
# 1041                       [Keittiö, Sisustustrendit]
# 1131                                       [Kolumnit]
# 1169                 [Sisustusideat, Sisustustrendit]
# 1397                                      [Kilpailut]
# 2073                                    [Autouutiset]
# 2653              [Autouutiset, Liikenneturvallisuus]
# 2721                                       [Kolumnit]
# 2792                                      [Kulttuuri]
# 2862                                        [Ihmiset]
# 2901                                      [Kulttuuri]
# 3340              [Autouutiset, Liikenneturvallisuus]
# 3619                                               []
# 3955                                      [Osallistu]
# 3990                                      [Apu-kerho]
# 4435  [Ihmissuhteet, Julkkikset, Alkoholi , Päihteet]
# 4440                                         [Ilmiöt]
# 4466             [Musiikki, Ihmissuhteet, Julkkikset]
# 4671                                      [Apu-kerho]
# 4730                         [Ihmissuhteet, Teatteri]
# 4754             [Ihmissuhteet, Teatteri, Julkkikset]
# 4926                                         [Luonto]
# 4961    [Autouutiset, Liikenneturvallisuus, Liikenne]
# 5244                                [Apu-kerho, Viro]
# 5338                                    [Autouutiset]
# 5462                    [Viihde, Ihmiset, Julkkikset]
# 5512                    [Viihde, Ihmiset, Julkkikset]
# 5776                                [Tanssi, Baletti]
# 5874                                    [Autouutiset]
# 5985                        [Autouutiset, Autokauppa]
# 6148                [Ilmiöt, Yhdysvallat, Politiikka]
# 6281                [Mieli, Palautuminen, Meditaatio]
# 6397                                     [Vitamiinit]
# 6404                                          [Mieli]
# 6621         [Vitamiinit, Ruokavaliot, Ravintoaineet]
# 6624                [Hiusmallit, Hiukset, Kampaukset]
# 6631                [Hiusmallit, Hiukset, Kampaukset]
# 6838                      [Rakkaus, Parisuhde, Mieli]
# 7231             [Hiusmallit, Hiukset, Hiusten hoito]
#
#                                             description  \
# 71    Moni meistä haluaisi raivata kalenteriinsa lis...
# 195   Joulukuusi kotiin kannettuna ja juhlavaksi kor...
# 330   Joulun varmin vinkki on antaa lahjaksi kestävä...
# 503   Haaveiletko pienestä tulisijasta, joka toisi k...
# 558   Arabia julkisti uuden muumimukin. Seesteisen t...
# 575   Santeri oli miettinyt kosintaa pitkin kevättä ...
# 669   Miltä porkkanan, kurkun tai tomaatin kuuluu nä...
# 688   Toni Goltz uskoo, että edulliset minitalot tek...
# 717   Kuumin mansikka-aika on käsillä juuri nyt. On ...
# 760   Asuntomessujen kohteissa 26–33 on huomioitu mu...
# 762   Porin asuntomessukohteiden 3–15 joukossa on ni...
# 812   Pensasangervot ovat loistovalinta jokaiseen pu...
# 1041  Keittiötrendit 2018 ovat täynnä syviä värimaai...
# 1131  Olga koittaa vaalia säästäväisyyttä ja analyso...
# 1169  Keveillä avohyllyillä saa säilytystilaa ja elo...
# 1397  Eeva viettää 85-vuotisjuhlaansa rakkauden merk...
# 2073  Suomalainen Energiaosuuskunta, SEO, perustetti...
# 2653  Lähes kuusi kymmenestä Liikenneturvan kyselyyn...
# 2721  "Mikä siinä on, että aaltojen kohina ei häirit...
# 2792  Syytökset sinkoilevat henkilöstä toiseen, ja t...
# 2862  Sanna Savikko on oppinut Oivalta kärsivällisyy...
# 2901  Saaren järkyttynyt väki törmää odottamattomaan...
# 3340  Perheen karvainen jäsen on mukavaa seuraa myös...
# 3619  Hanna Sumaria, 60, pidetään sanavalmiina naise...
# 3955  Matkalla tutustumme Utön historiaan ja saarell...
# 3990  Tervetuloa tutustumaan Suomen eteläisimpään as...
# 4435  Milana Misic kertoo traagisen tarinansa Merja ...
# 4440  Imagen autokoulun ensimmäisellä oppitunnilla S...
# 4466  Poliisit olivat tuttu näky Milana Misicin laps...
# 4671  Toukokuista Apu-kerhon risteilyä tahdittaa suo...
# 4730  Marjatta Leppästä ja Marja Saloa yhdistää kaks...
# 4754  Rakastettu kapellimestari Jaakko Salo menehtyi...
# 4926  Turun yliopiston tutkijat selvittivät myanmari...
# 4961  Liikenneturva kysyi joulukuussa 2017 suomalais...
# 5244  Lähde Apu-kerhon matkassa risteilemään ja tans...
# 5338  Haaveissa valkoisena kimmeltävä hanki, taianom...
# 5462  - Naurattaa, kun hädin tuskin kolmekymppisistä...
# 5512  - Tekee mieli karsia heikot lenkit, mutta nehä...
# 5776  Muumipeikko ja taikurin hattu on viehättävä ko...
# 5874  Suomalainen Energiaosuuskunta SEO juhlii tasak...
# 5985  Musta on ohittanut valkoisen suosituimpana aut...
# 6148  Pyysimme Avun lukijoita kertomaan omin sanoin ...
# 6281  Maria Guzenina juo aamukahvinsa aina sängyssä,...
# 6397  Katja Ketun saa kukoistamaan eläinten seura, u...
# 6404  Laura Voutilaisen kukoistuksen lähteitä ovat m...
# 6621  Marjojen terveyshyödyt häipyvät, jos keräät, s...
# 6624  Polkkatukka on aina muotia. Uusi ilme syntyy e...
# 6631  Lyhyet hiusmallit ovat yllättävän monipuolisia...
# 6838  Häpeä syntyy siellä, missä rakkaus väistyy. Tu...
# 7231  Hiustrendien avainsana on tänä keväänä huolett...
#
#                                                      id       mainCategory  \
# 71    QXJ0aWNsZTpiOTcyZmI2NS05NjRlLTQ1NTYtODVlNS05MG...
# 195   QXJ0aWNsZTplZGM2MzhjZS1kNGJlLTRhMTctOGQ3MS00ND...          Viherpiha
# 330   QXJ0aWNsZTo1ZTJhN2NmZC1jZGI4LTQzODMtOTkzZS1lNT...           Avotakka
# 503   QXJ0aWNsZTpmOWEzMDhjNi1iZTkzLTRmNTktYmU1Yy04Mz...
# 558   QXJ0aWNsZTozMjM1NGM1Ny1kNjY0LTRhYTAtYWZhNi05Nz...      Meillä kotona
# 575   QXJ0aWNsZTo4MTU2Y2ZlZi0zNmY1LTQyMDMtYmYyMy1hNj...      Meillä kotona
# 669   QXJ0aWNsZTphNjYyMzMyOS1lZWI3LTRhMmItOWY2Yy1hOW...      Meillä kotona
# 688   QXJ0aWNsZToxZGZlMWMyOC05MWRkLTQ3NzItYTMzZS1kOT...      Meillä kotona
# 717   QXJ0aWNsZTo0NjRhODMyNC1jMjgyLTQ4YjMtYjQyNy03ND...               Maku
# 760   QXJ0aWNsZTphYWJhMjQxYy1iYThiLTRkMjAtOGRlMi1kNW...      Meillä kotona
# 762   QXJ0aWNsZTpmM2RkMWViZC1hMDc5LTQ5MzUtYjIwMS1kNz...      Meillä kotona
# 812   QXJ0aWNsZTplZTg3MzExYi05MGVjLTRjMGUtOTM4Ni1hZj...          Viherpiha
# 1041                               QXJ0aWNsZTpEdmY3YWhR           Avotakka
# 1131                               QXJ0aWNsZToxM1YyVTUx         Kotivinkki
# 1169                               QXJ0aWNsZTpaMEFnM01k           Avotakka
# 1397  QXJ0aWNsZTo1YWU5ZDlhYS05OWE3LTRhOWQtODE2Zi01ZG...               Eeva
# 2073  QXJ0aWNsZTplMzE1ODNiNC1iNWQyLTRjYjMtYTg5NC1hMW...          Tuulilasi
# 2653  QXJ0aWNsZTpkZGY5NDA1Yi04OWEzLTQ2NjAtOTRmMi1iNm...          Tuulilasi
# 2721  QXJ0aWNsZTpjNGE4MDk1YS1hMjExLTQ2NGUtYjJhYi03OW...               Eeva
# 2792  QXJ0aWNsZTo5OGFlOTg5ZS0xNGQxLTQxNWYtODhlOS02ZW...                Apu
# 2862  QXJ0aWNsZTowYjc0MjI3ZS04NmRhLTRmZmItYTNmYy04Nj...               Eeva
# 2901  QXJ0aWNsZTpjZGE0YjY2Ny1iMWRjLTQyMTItOTExYS02ZG...                Apu
# 3340  QXJ0aWNsZTowOTYzMmZlOC1kYjBlLTRiOTQtYWFjYS0wOG...          Tuulilasi
# 3619  QXJ0aWNsZTo0Y2JkNGFhYy04MjQ1LTRjNGQtODYzMi0yMW...               Eeva
# 3955                   QXJ0aWNsZTpIZHNSeHQ3VnpPM1ZNdQ==               Eeva
# 3990                   QXJ0aWNsZTpuOFVGSHNXVUZxWklCYQ==                Apu
# 4435                               QXJ0aWNsZTpGeTh1eVQ5                Apu
# 4440                               QXJ0aWNsZTp2OFJWMTN1              Image
# 4466                               QXJ0aWNsZTpZY2VWLTZE                Apu
# 4671                               QXJ0aWNsZTpMQzByalRf                Apu
# 4730                               QXJ0aWNsZTp3cXNxQ21G                Apu
# 4754                               QXJ0aWNsZTo1NFN4SFhH                Apu
# 4926                               QXJ0aWNsZTo4Mk5Ybm1W                Apu
# 4961  QXJ0aWNsZTplNGFiMzE4Zi1lMGZhLTQyNmYtYmVjYy0wMm...          Tuulilasi
# 5244                               QXJ0aWNsZToyZlVubWFK                Apu
# 5338  QXJ0aWNsZTowYWVkNmQwNy01MTdjLTQ5ZDgtYWExNi03Mj...          Tuulilasi
# 5462                               QXJ0aWNsZTphQUMzYnpC                Apu
# 5512                               QXJ0aWNsZTpSdWRaT3FG                Apu
# 5776                               QXJ0aWNsZTpyeGJmaHVs                Apu
# 5874  QXJ0aWNsZToxMGQ5ZTk3NS0xNjE3LTRjNmQtOGVhMy1lNT...          Tuulilasi
# 5985  QXJ0aWNsZTpiZGFkMDE5OS03NzkzLTQwZTMtYjUyNy0xM2...          Tuulilasi
# 6148                               QXJ0aWNsZTpRTjV0YU1M                Apu
# 6281  QXJ0aWNsZTo1NTFjMzUyNi0xNDJhLTRiZWEtYjJkZC1mYW...          Voi hyvin
# 6397  QXJ0aWNsZTpkN2IwOWI5NS03ODUzLTQ0NzYtODNmNC1iND...          Voi hyvin
# 6404  QXJ0aWNsZTo1ODQ3NDljMi0xMTZiLTQ1NzktOWEyZS0yNz...          Voi hyvin
# 6621  QXJ0aWNsZTo5OWQ4YzNiOS1iOWQwLTRjZjYtYWQ4Yy03Nj...  Kauneus & Terveys
# 6624  QXJ0aWNsZTpkZGM2ZWQwNS01YTA1LTRkODgtYjQ2ZC03Yj...  Kauneus & Terveys
# 6631  QXJ0aWNsZTpkNWY4ODJjOS05M2JjLTRlMjUtYTM0ZS0yNG...  Kauneus & Terveys
# 6838                               QXJ0aWNsZTo4VDBLckFI          Voi hyvin
# 7231                               QXJ0aWNsZTpaT1ZNdEx1  Kauneus & Terveys
#
#           published          subCategory  \
# 71    1547640000000              Ihmiset
# 195   1543988100000     Piha ja puutarha
# 330   1541071440000             Sisustus
# 503   1536829200000  Rakenna ja remontoi
# 558   1535536731000             Sisustus
# 575   1535020361000              Ihmiset
# 669   1532334348000     Piha ja puutarha
# 688   1531812180000  Rakenna ja remontoi
# 717   1530875534000                Ruoka
# 760   1529566500000  Rakenna ja remontoi
# 762   1529565300000  Rakenna ja remontoi
# 812   1528197600000     Piha ja puutarha
# 1041  1522140300000             Sisustus
# 1131  1519719000000              Ihmiset
# 1169  1518598560000             Sisustus
# 1397  1548841493000            Ajanviete
# 2073  1542196800000    Autot ja liikenne
# 2653  1537870849000    Autot ja liikenne
# 2721  1537182900000         Puheenaiheet
# 2792  1536480000000            Ajanviete
# 2862  1536073440000         Puheenaiheet
# 2901  1535961600000            Ajanviete
# 3340  1532413771000    Autot ja liikenne
# 3619  1530075780000         Puheenaiheet
# 3955  1527246900000            Ajanviete
# 3990  1527073200000             Matkailu
# 4435  1524419100000         Puheenaiheet
# 4440  1524387600000         Puheenaiheet
# 4466  1524203940000         Puheenaiheet
# 4671  1522915200000             Matkailu
# 4730  1522474020000            Kulttuuri
# 4754  1522294020000         Puheenaiheet
# 4926  1521225000000         Puheenaiheet
# 4961  1521095743000    Autot ja liikenne
# 5244  1519803126000             Matkailu
# 5338  1519283865000    Autot ja liikenne
# 5462  1518411667000         Puheenaiheet
# 5512  1518076853000         Puheenaiheet
# 5776  1516874201000            Kulttuuri
# 5874  1516355827000    Autot ja liikenne
# 5985  1516003819000    Autot ja liikenne
# 6148  1515064110000         Puheenaiheet
# 6281  1547555190000          Hyvinvointi
# 6397  1542090270000          Hyvinvointi
# 6404  1541511221000          Hyvinvointi
# 6621  1530537429000    Treeni ja ravinto
# 6624  1530526571000              Kauneus
# 6631  1529776504000              Kauneus
# 6838  1523440800000          Hyvinvointi
# 7231  1519912163000              Kauneus
#
#                                                   title     type         venue
# 71    Äänikirjat koukuttivat Lilou’s Crush -blogin H...  Article  meillakotona
# 195   Joulukuusi tekee juhlan! Perinteinen metsäkuus...  Article  meillakotona
# 330   Sisustusarkkitehdin 6 valintaa: joululahjavink...  Article  meillakotona
# 503   Romanttiset puuhellat ja pienet takat – luo tu...  Article  meillakotona
# 558   Uunituoreessa muumimukissa Muumipeikko ihailee...  Article  meillakotona
# 575   Santeri halusi kosia, mutta sormus puuttui – v...  Article  meillakotona
# 669   Nehän halaavat! Rakastuneet porkkanat, peukutt...  Article  meillakotona
# 688   Talo ilman muovia, myrkkyjä ja kulmia – tehora...  Article  meillakotona
# 717   Viipaloi, sokeroi ja säilö rasiaan – näin onni...  Article  meillakotona
# 760                   Porin asuntomessut: kohteet 26–33  Article  meillakotona
# 762                    Porin asuntomessut: kohteet 3–15  Article  meillakotona
# 812   Pensasangervot hurmaavat kauniilla kukinnallaa...  Article  meillakotona
# 1041  Keittiötrendit 2018: syviä sävyjä, puuta ja me...  Article  meillakotona
# 1131  Kaiken tavarapaljouden alla analysoin itseäni:...  Article  meillakotona
# 1169  Hyllyjen aika! Asettele lempiesineet seinälle ...  Article  meillakotona
# 1397                               Kirjoita rakkaudesta  Article           apu
# 2073  SEO juhlii 40-vuotista taivaltaan: "Kotimainen...  Article           apu
# 2653  Turvavyön käytössä linja-autoissa paljon paran...  Article           apu
# 2721                     Riitta Nykänen: Maiseman voima  Article           apu
# 2792         Avun kesädekkari: Kultainen kesä, osa 8/10  Article           apu
# 2862  Aamu-tv:n juontaja Sanna Savikko otti rescueko...  Article           apu
# 2901         Avun kesädekkari: Kultainen kesä, osa 5/10  Article           apu
# 3340  Näin matkustat turvallisesti koiran kanssa aut...  Article           apu
# 3619  Hanna Sumari: "Olen pohtinut, rakastiko äiti m...  Article           apu
# 3955  Eevan lukijamatka: Utö – Suomen eteläisin asut...  Article           apu
# 3990    Apu-kerhon matka: Utön majakkasaari 4.–5.8.2018  Article           apu
# 4435  Kulissit peittivät myrskyn: Katso Milana Misic...  Article           apu
# 4440                                     "Se on kaasu."  Article           apu
# 4466  Laila Kinnusen veljet toivat Milana Misicin la...  Article           apu
# 4671  Lähde Apu-kerhon kanssa Koko laiva laulaa -ris...  Article           apu
# 4730  Yösyöttö-elokuvasta tuttu näyttelijä Marja Sal...  Article           apu
# 4754  Rakkaus Jaakko Saloon yhdistää näyttelijä Marj...  Article           apu
# 4926  Norsujen persoonallisuutta selvitettiin: ovat ...  Article           apu
# 4961   Kuljeta lemmikkisi oikein autossa – tässä vinkit  Article           apu
# 5244  Apu-kerhon Suurtanssit-risteily Tallinnaan 18....  Article           apu
# 5338      Suksiboksi tuo tilaa – muista oikea kiinnitys  Article           apu
# 5462  Anita Hirvonen ei menisi Linnan juhliin: "Ne j...  Article           apu
# 5512  Katja Ståhl Selviytyjistä: "Pelkään, että minu...  Article           apu
# 5776           Tanssiarvio: Miten käy Muumilta baletti?  Article           apu
# 5874  SEO täyttää 40 vuotta: "Huoltoasema on yhä ihm...  Article           apu
# 5985  Musta ohitti valkoisen suosituimpana autovärin...  Article           apu
# 6148  Lukijat kertovat sukunsa ja lähipiirinsä tarin...  Article           apu
# 6281           Maria Guzenina: Kukoistan, kun rauhoitun  Article         terve
# 6397        Katja Kettu: Kukoistan, kun pulahdan mereen  Article         terve
# 6404  Laura Voutilainen: Kukoistan, koska kirjoitan ...  Article         terve
# 6621  Hukkaatko marjojen terveyshyödyt väärällä käsi...  Article         terve
# 6624  Polkkatukka: 12 muodikkainta mallia ja jännät ...  Article         terve
# 6631  Lyhyt tukka sinullekin: Naisellinen nyrhitty t...  Article         terve
# 6838                       Tarvitsemme eniten rakkautta  Article         terve
# 7231  Polkkatukka, vahvat värit ja otsatukka – tässä...  Article         terve
